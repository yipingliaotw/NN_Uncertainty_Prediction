# %%
import sys
sys.path.append('../')
from models.dropout import NaiveDropout
import numpy as np
from utils.plot import plot
import matplotlib.pyplot as plt
from utils.gen_data import gen_data
# Out:
# Using TensorFlow backend.

# %%
data_x, data_y = gen_data()

# %%
model = NaiveDropout(num_models=30, num_epochs=100, batch_size=100)
x = np.linspace(-4, 4, 100)
mean, variance = model.fit_pred(data_x, data_y, x[:, np.newaxis])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# pred (Dense)                 (None, 1)                 33
# ...
# Total params: 2,241
# Trainable params: 2,241
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1960 samples, validate on 490 samples
# Epoch 1/100
# ...

# %%
plot(mean,variance, data_x, data_y, x)

# %%
plt.figure(figsize=(12, 8))
plt.plot(x, np.abs(variance))
