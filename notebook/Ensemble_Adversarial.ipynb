# %%
import sys
sys.path.append('../')
from models.EnsembledNN_Adversarial import EnsembledNN_Adversarial
from utils.plot import plot
import matplotlib.pyplot as plt
import numpy as np
from utils.gen_data import gen_data

# %%
data_x, data_y = gen_data()

# %%
ems_adv = EnsembledNN_Adversarial(num_models=15, num_epochs=200, batch_size=200, adversarial_eps=0.1)

# %%
x = np.linspace(-4, 4, 100)
mean, variance = ems_adv.fit_pred(data_x, data_y, x[:, np.newaxis])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                128
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# pred (Dense)                 (None, 1)                 33
# ...
# Total params: 2,241
# Trainable params: 2,241
# Non-trainable params: 0
# _________________________________________________________________
# ...
# ***epoch:  0 ** train loss:13.579 ** val loss:14.809***
# ***epoch:  1 ** train loss:9.447 ** val loss:6.759***
# ***epoch:  2 ** train loss:7.102 ** val loss:5.841***
# ***epoch:  3 ** train loss:6.069 ** val loss:5.215***
# ...

# %%
plot(mean, variance, data_x, data_y, x, "Ensemble_NN_Adversarial")

# %%
plt.figure(figsize=(12, 8))
plt.plot(x, variance)
