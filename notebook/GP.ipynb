# %%
import sys
sys.path.append('../')
from models.GPRegression import GPRegression
from utils.plot import plot
import matplotlib.pyplot as plt
import numpy as np
from utils.gen_data import gen_data

# %%
data_x, data_y = gen_data()

# %%
param_l = 2.3
param_sigma = np.sqrt(225)
sigma_noise = 5
x = np.linspace(-4, 4, 100)
gp = GPRegression(param_sigma, param_l, sigma_noise)
m, v = gp.fit_pred(data_x, data_y, x)

# %%
plot(m, np.diag(v), data_x, data_y, x, "GP")

# %%
plt.figure(figsize=(12, 8))
plt.plot(x, np.diag(v))
